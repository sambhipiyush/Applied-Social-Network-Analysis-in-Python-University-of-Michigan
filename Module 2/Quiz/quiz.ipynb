# %%
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 1. (1/1)

# %%
g = nx.Graph()

# %%
g.add_edges_from(
    [
        ('A','B'), ('A','C'), ('A','D'), ('A','E'), ('A','F'),
        ('B','C'), ('B','F'), ('C','D'), ('C','F'),
        ('D','E'), ('D','F'),
        ('E','F')
    ]
)

# %%
nx.draw_networkx(g)

# %%
nx.clustering(g, 'F')
# Out:
# 0.7

# %% [markdown]
# # 2. (1/1)

# %% [markdown]
# Graph **A** has higher average LCC but lower trasitivity then graph **B**

# %% [markdown]
# # 3. (1/1)

# %%
g = nx.Graph()

# %%
g.add_edges_from(
    [
        ('A','B'), ('A','C'),
        ('B','D'),
        ('C','D'), ('C','E'),
        ('D','E'), ('D','G'),
        ('E','G'),
        ('G','F')
    ]
)

# %%
nx.draw_networkx(g)

# %%
nx.radius(g)
# Out:
# 2

# %%
nx.diameter(g)
# Out:
# 4

# %%
g_noG = g.copy()
g_noG.remove_node('G')
nx.draw_networkx(g_noG)

# %%
nx.is_connected(g_noG)
# Out:
# False

# %%
t = nx.bfs_tree(g, 'A')
nx.draw_networkx(t)

# %%
nx.center(g)
# Out:
# ['D', 'E']

# %%
nx.periphery(g)
# Out:
# ['A', 'F']

# %%
nx.eccentricity(g)
# Out:
# {'A': 4, 'B': 3, 'C': 3, 'D': 2, 'E': 2, 'G': 3, 'F': 4}

# %% [markdown]
# # 4. (1/1)

# %%
g = nx.Graph()

# %%
g.add_edges_from(
    [
        ('A','C'), ('A','D'), ('C','G'), ('G','E'), ('D','E'),
        ('D','B'), ('D','H'), ('E','H'), ('B','H'), ('H','F'),
        ('I','J'), ('I', 'K')
    ]
)

# %%
nx.draw_networkx(g)

# %%
nx.is_connected(g)
# Out:
# False

# %%
nx.number_connected_components(g)
# Out:
# 2

# %%
g_noEG = g.copy()
g_noEG.remove_edge('E', 'G')
nx.number_connected_components(g_noEG)
# Out:
# 2

# %%
nx.draw_networkx(g_noEG)

# %%
nx.clustering(g, 'I'), nx.clustering(g, 'J'), nx.clustering(g, 'K'),
# Out:
# (0, 0, 0)

# %%
g.add_edge('E', 'J')

# %%
nx.is_connected(g)
# Out:
# True

# %% [markdown]
# # 5. (0/1)

# %%
g1 = nx.MultiDiGraph()
g2 = nx.MultiDiGraph()
g3 = nx.MultiDiGraph()

# %%
g1.add_edges_from(
    [
        ('A','B'), ('A','C'),
        ('B','C'), ('C','B'),
        ('D','C'), ('E','B'),
    ]
)
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
g2.add_edges_from(
    [
        ('A','D'), ('A','B'), ('B','A'), ('B','C'),
        ('A','C'), ('C','A'), ('D','E'), ('E','C')
    ]
)
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]

# %%
g3.add_edges_from(
    [
        ('A','C'), ('B','A'), ('A','D'), ('C','B')
    ]
)
# Out:
# [0, 0, 0, 0]

# %%
nx.draw_networkx(g1, nx.kamada_kawai_layout(g1))

# %%
nx.draw_networkx(g2, nx.kamada_kawai_layout(g2))

# %%
nx.draw_networkx(g3, nx.kamada_kawai_layout(g3))

# %%
(nx.is_strongly_connected(g1),
 nx.is_strongly_connected(g2),
 nx.is_strongly_connected(g3))
# Out:
# (False, True, False)

# %%
g1_str = g1.copy()
g1_str.add_edge('C', 'D')
nx.is_strongly_connected(g1_str)
# Out:
# False

# %%
nx.draw_networkx(g1_str, nx.kamada_kawai_layout(g1_str))

# %%
nx.draw_networkx(g2, nx.kamada_kawai_layout(g2))

# %%
nx.node_connectivity(g2), nx.minimum_node_cut(g2)
# Out:
# (1, {'C'})

# %%
nx.edge_connectivity(g2), nx.minimum_edge_cut(g2)
# Out:
# (1, {('C', 'A')})

# %%
g3_str = g3.copy()
g3.add_edge('D', 'A')
nx.is_strongly_connected(g3_str)
# Out:
# False

# %%
# More then one edge is needed

# %%
nx.draw_networkx(g3_str, nx.kamada_kawai_layout(g3_str))

# %% [markdown]
# # 6. (1/1)

# %% [markdown]
# [x] The closures of an airport (...)
#
# [x] Network robustness measures (...)
#
# [x] Adding edges can never (...)

# %% [markdown]
# # 7. (1/1)

# %%
g = nx.Graph()

# %%
g.add_edges_from(
    [
        ('A','B'), ('A','C'), ('A','F'),
        ('B','C'), ('B','D'), ('B','E'),
        ('C','E'), ('C','F'), 
        ('D','E'),
        ('E','F'), ('E','G'), ('E','H'), 
        ('G','H'), ('G','K'), ('G','M'),
        ('H','M'), ('H','N'), 
        ('K','M'), ('K','N')
    ]
)

# %%
nx.average_clustering(g), nx .transitivity(g)
# Out:
# (0.5090909090909089, 0.4528301886792453)

# %%
nx.node_connectivity(g)
# Out:
# 1

# %% [markdown]
# # 8. (1/1)

# %%
nx.edge_connectivity(g)
# Out:
# 2

# %%
nx.edge_connectivity(g), nx.minimum_edge_cut(g)
# Out:
# (2, {('G', 'E'), ('H', 'E')})

# %%
nx.node_connectivity(g), nx.minimum_node_cut(g)
# Out:
# (1, {'E'})

# %% [markdown]
# # 9. (1/1)

# %%
g = nx.DiGraph()

# %%
g.add_edges_from(
    [
        ('D','A'), ('D','B'), ('B','A'),
        ('A','C'), ('C','E'), ('C','B'),
        ('E','F'), ('E','H'), ('J','E'),
        ('H','J'), ('H','K'), ('K','J'), 
        ('F','H'), ('F','K'), ('F','G'),
        ('G','K')
    ]
)

# %%
len(sorted(nx.all_simple_paths(g, 'D', 'K')))
# Out:
# 8

# %% [markdown]
# # 10. (1/1)

# %% [markdown]
# [x] Removing node F and H
#
# [x] Removing edges (H,K) and (E,F)

# %% [markdown]
# EOF
